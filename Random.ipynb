# %%
from fastai.data.all import *
from PIL import Image

# %%
test = Image.open('test/test.jpg').resize((40,40)).rotate(-90)

# %%
test
# Out:
# <PIL.Image.Image image mode=RGB size=40x40 at 0x7F799CD19AF0>
